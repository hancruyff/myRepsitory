# %%
import sqlite3
import pandas as pd
from sqlite3 import connect

DB_PATH ='/content/drive/MyDrive/2023가을, 빅데이터응용/chinook.db'

# %%
conn=sqlite3.connect(DB_PATH)
cursor=conn.cursor()
table=pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'",conn)
table.head()
# Out:
#               name
# 0           albums
# 1  sqlite_sequence
# 2          artists
# 3        customers
# 4        employees

# %%
table=pd.read_sql_query("SELECT * FROM employees",conn)
table.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane           IT Manager        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with connect(DB_PATH) as db:
    db.execute("""
        CREATE TABLE IF NOT EXISTS ITEMS(
            id integer primary key autoincrement,
		        code text not null,
		        artist text not null,
		        price integer not null)
    """)

# %%
table=pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'",conn)
table.head()
# Out:
#               name
# 0           albums
# 1  sqlite_sequence
# 2          artists
# 3        customers
# 4        employees

# %%
df=pd.DataFrame(columns=['id', 'code', 'artist', 'price'])
df.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: [id, code, artist, price]
# Index: []>

# %%
INSERT_SQL= 'INSERT INTO ITEMS(id, code, artist, price) VALUES(?,?,?,?);'
data=(
    (1, 'ABC111', '마룬5', 35000),
		(2, 'DFG222', '아리아나그란데', 45000),
		(3, 'HIJ333', 'NCT', 30000)
    )
cursor.executemany(INSERT_SQL,data)
conn.commit()

# %%
SQL='SELECT * FROM ITEMS;'
cursor.execute(SQL)
R=cursor.fetchall()
for i in R:
  print(i)
# Out:
# (1, 'ABC111', '마룬5', 35000)
# (2, 'DFG222', '아리아나그란데', 45000)
# (3, 'HIJ333', 'NCT', 30000)

# %%
q="""SELECT * FROM ITEMS;"""
pd.read_sql_query(q,conn)
# Out:
#    id    code   artist  price
# 0   1  ABC111      마룬5  35000
# 1   2  DFG222  아리아나그란데  45000
# 2   3  HIJ333      NCT  30000

# %%
SQL='SELECT * FROM employees order by EmployeeId asc limit 10;'
cursor.execute(SQL)
R=cursor.fetchall()
for i in R:
  print(i)
# Out:
# (1, 'Adams', 'Andrew', 'General Manager', None, '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com')
# (2, 'Edwards', 'Nancy', 'Sales Manager', 1, '1958-12-08 00:00:00', '2002-05-01 00:00:00', '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com')
# (3, 'Peacock', 'Jane', 'IT Manager', 2, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com')
# (4, 'Park', 'Margaret', 'Sales Support Agent', 2, '1947-09-19 00:00:00', '2003-05-03 00:00:00', '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com')
# ...

# %%
SQL='SELECT * FROM customers WHERE Country="Austria";'
cursor.execute(SQL)
R=cursor.fetchall()
for i in R:
  print(i)
# Out:
# (7, 'Astrid', 'Gruber', None, 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', '+43 01 5134505', None, 'astrid.gruber@apple.at', 5)

# %%
UPDATE_SQL='UPDATE employees SET Title="IT Manager" WHERE Firstname="Jane";'
cursor.execute(UPDATE_SQL)
conn.commit()

cursor.execute('SELECT * FROM employees WHERE Firstname="Jane";')
updated_employees = cursor.fetchall()
print(updated_employees)
# Out:
# [(3, 'Peacock', 'Jane', 'IT Manager', 2, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com')]

# %%
DELETE_SQL='DELETE FROM ITEMS WHERE artist="마룬5";'
cursor.execute(DELETE_SQL)
conn.commit()
q="""SELECT * FROM ITEMS;"""
pd.read_sql_query(q,conn)
# Out:
#    id    code   artist  price
# 0   2  DFG222  아리아나그란데  45000
# 1   3  HIJ333      NCT  30000
